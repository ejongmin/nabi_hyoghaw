# %% [markdown]
# # 나비효과 MVP v3 — Colab 실행\nDrive에 올려둔 프로젝트 폴더에서 실행하세요.\n

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/nabi_effect_mvp

# %%
# !python -m pip install -r requirements.txt

# %%
# !python -m src.cli pipeline --config configs/base_colab_drive.yaml
